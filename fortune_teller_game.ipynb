# %% [markdown]
# # Fortune Teller Game
# You'll create a program that allows players to roll a die and get a fortune based on the number. In addition, your program will give three fortunes: bad fortune, average fortune, and a good fortune.
#
# ![JSA_magic-8-ball_1.png](data:image/png;base64,...)

# %%
# Create your program here.
import random
def fortune_teller():
    user_num = input("Welcome to your fortune teller! I know how good your fortune will be based on your guesses. I know it sounds stupid but trust me it works. Enter roll here: " )
    if user_num == "roll" :
        num = random.randint(1,6)
        if num == 1:
            print("You will fall into a manhole.")
            fortune_teller()
        elif num == 2:
            print("You will lose something valuable.")
            fortune_teller()
        elif num == 3:
            print("Good job, you found the only way to get a good fortune.")
            again = input("What do you want: ")
            if input == input: 
                print("Yee shall ask, yee shall recieve.")
                fortune_teller()
        elif num == 4:
            print("Nothing happens, you get a normal day. Boring! DO better!")
            fortune_teller()
        elif num == 5:
            print("You get fired.")
            fortune_teller()
        elif num == 6:
            print("I'll see you never!")
            fortune_teller()
    elif user_num == "exit":
        return("Bye see you later!")
    else:
        print("I don't understand, please try again")

fortune_teller()
# Out:
# Welcome to your fortune teller! I know how good your fortune will be based on your guesses. I know it sounds stupid but trust me it works. Enter roll here:  roll
# You get fired.
# Welcome to your fortune teller! I know how good your fortune will be based on your guesses. I know it sounds stupid but trust me it works. Enter roll here:  roll
# I'll see you never!
# Welcome to your fortune teller! I know how good your fortune will be based on your guesses. I know it sounds stupid but trust me it works. Enter roll here:  roll
# You will lose something valuable.
# Welcome to your fortune teller! I know how good your fortune will be based on your guesses. I know it sounds stupid but trust me it works. Enter roll here:  roll
# You will fall into a manhole.
